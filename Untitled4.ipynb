# %%
""" XGbost"""
import xgboost as xgb
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler,LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\gaurav\covid_toy.csv")
df.head()
df["fever"].fillna(df["fever"].mean(),inplace=True)
l = LabelEncoder()
df["gender"] = l.fit_transform(df["gender"])
df["cough"] = l.fit_transform(df["cough"])
df["city"] = l.fit_transform(df["city"])
df["has_covid"] = l.fit_transform(df["has_covid"])
X = df.drop("fever",axis=1)
y = df["fever"]
df.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_700\1134372626.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fever"].fillna(df["fever"].mean(),inplace=True)
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=30)
model = GradientBoostingRegressor(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)

model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=200, random_state=42)

# %%
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)

print("R2 Score:", r2)
print("RMSE:", rmse)
# Out:
# R2 Score: -1.074794295884498
# RMSE: 5.863623689180446

# %%
live= pd.DataFrame({
    'age':[60], 
    'gender':[1], 
    'cough':[0], 
    'city':[2], 
    'has_covid':[0]
})
p = model.predict(live)
p
# Out:
# array([100.20224123])

# %%
"""Random Forest """
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, probplot
from sklearn.preprocessing import StandardScaler,MinMaxScaler,FunctionTransformer,LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error,confusion_matrix
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\gaurav\covid_toy.csv")
df.head()
df["fever"].fillna(df["fever"].mean(),inplace=True)
l = LabelEncoder()
df["gender"]=l.fit_transform(df["gender"])
df["cough"] =l.fit_transform(df["cough"])
df["city"] = l.fit_transform(df["city"])
X = df.drop("has_covid",axis=1)
y = df["has_covid"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=20)
df.isnull().sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14456\989066750.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fever"].fillna(df["fever"].mean(),inplace=True)
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
#applying random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=20
)

rf.fit(X_train, y_train)
y_pr = rf.predict(X_test)
acc = accuracy_score(y_test,y_pr)
print("this is score of accuracy",acc)
plt.figure()
plt.bar(X.columns, rf.feature_importances_)
plt.xlabel("Fe")
plt.ylabel("Importance")
plt.title("Feature Importance - Has covid")
plt.show()
# Out:
# this is score of accuracy 0.43333333333333335

# %%
plt.figure()
plt.hist(df["has_covid"])
plt.xlabel("has_covid (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.title("Covid Distribution")
plt.show()

# %%
cm = confusion_matrix(y_test, y_pr)

plt.figure()
plt.imshow(cm)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.colorbar()
plt.show()

# %%
live = pd.DataFrame({
    'age':[60], 
    'gender':[1], 
    'fever':[103.0], 
    'cough':[0], 
    'city':[2]
})

# %%
probabilty = rf.predict_proba(live)
prob_pos = probabilty[0][1]
label = "Covid" if prob_pos>0.50 else "No Covid"
print(prob_pos)
print(label)
# Out:
# 0.705
# Covid

# %%
""" Decision Tree"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, probplot
from sklearn.preprocessing import StandardScaler,MinMaxScaler,FunctionTransformer,LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\gaurav\covid_toy.csv")
df.head()
l = LabelEncoder()
df["gender"]=l.fit_transform(df["gender"])
df["cough"] =l.fit_transform(df["cough"])
df["city"] = l.fit_transform(df["city"])
X = df.drop("has_covid",axis=1)
y = df["has_covid"]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=30)
from sklearn.tree import DecisionTreeClassifier
treemodel=DecisionTreeClassifier(max_depth=4)
treemodel.fit(X_train,y_train)
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.4, 0.9, 'x[2] <= 98.5\ngini = 0.496\nsamples = 70\nvalue = [38, 32]'),
#  Text(0.2, 0.7, 'x[4] <= 0.5\ngini = 0.463\nsamples = 22\nvalue = [8, 14]'),
#  Text(0.30000000000000004, 0.8, 'True  '),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3, 0.5, 'x[0] <= 81.5\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.2, 0.3, 'x[0] <= 7.5\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.1, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3, 0.1, 'gini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6, 0.7, 'x[0] <= 8.0\ngini = 0.469\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.5, 0.8, '  False'),
#  Text(0.5, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7, 0.5, 'x[0] <= 14.5\ngini = 0.454\nsamples = 46\nvalue = [30, 16]'),
#  Text(0.6, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
# ...

# %%
""" logistic"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, probplot
from sklearn.preprocessing import StandardScaler,MinMaxScaler,FunctionTransformer,LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
df=pd.read_csv(r"C:\Users\Lenovo\AppData\Local\Packages\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\LocalState\sessions\A6A521C45BF54CB40C63CBB6383398495351B936\transfers\2026-01\drug200.csv")
df.head()
X = df.drop("Cholesterol",axis=1)
y = df["Cholesterol"]
cat = X.select_dtypes(include=["object"]).columns
num = X.select_dtypes(exclude=["object"]).columns

# %%
pr = ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop="first",handle_unknown="ignore"),cat),
    ('num',StandardScaler(),num)
])
pr
# Out:
# ColumnTransformer(transformers=[('cat',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  Index(['Sex', 'BP', 'Drug'], dtype='object')),
#                                 ('num', StandardScaler(),
#                                  Index(['Age', 'Na_to_K'], dtype='object'))])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=40)
X_train.head()
m.fit(X_train,y_train)
y_pr = m.predict(X_test)
acc = accuracy_score(y_test,y_pr)
acc
# Out:
# 0.5833333333333334

# %%
m = Pipeline(steps=[
    ("pr",pr),
    ("logis",LogisticRegression())
])
m
# Out:
# Pipeline(steps=[('pr',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   Index(['Sex', 'BP', 'Drug'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Age', 'Na_to_K'], dtype='object'))])),
#                 ('logis', LogisticRegression())])

# %%
df.head(30)
# Out:
#     Age Sex      BP Cholesterol  Na_to_K   Drug
# 0    23   F    HIGH        HIGH   25.355  drugY
# 1    47   M     LOW        HIGH   13.093  drugC
# 2    47   M     LOW        HIGH   10.114  drugC
# 3    28   F  NORMAL        HIGH    7.798  drugX
# 4    61   F     LOW        HIGH   18.043  drugY
# 5    22   F  NORMAL        HIGH    8.607  drugX
# 6    49   F  NORMAL        HIGH   16.275  drugY
# 7    41   M     LOW        HIGH   11.037  drugC
# 8    60   M  NORMAL        HIGH   15.171  drugY
# 9    43   M     LOW      NORMAL   19.368  drugY
# 10   47   F     LOW        HIGH   11.767  drugC
# 11   34   F    HIGH      NORMAL   19.199  drugY
# 12   43   M     LOW        HIGH   15.376  drugY
# 13   74   F     LOW        HIGH   20.942  drugY
# 14   50   F  NORMAL        HIGH   12.703  drugX
# 15   16   F    HIGH      NORMAL   15.516  drugY
# 16   69   M     LOW      NORMAL   11.455  drugX
# 17   43   M    HIGH        HIGH   13.972  drugA
# 18   23   M     LOW        HIGH    7.298  drugC
# ...

# %%
l = pd.DataFrame({
    'Age':[39], 
    'Sex':["F"], 
    'BP':["LOW"], 
    'Na_to_K':[22.743], 
    'Drug':["drugY"]
})
pro = m.predict(l)
pro
# Out:
# array(['NORMAL'], dtype=object)

# %%
""" Multi Linear Regression"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, probplot
from sklearn.preprocessing import StandardScaler,MinMaxScaler,FunctionTransformer,LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
df = pd.read_csv(r"C:\Users\Lenovo\AppData\Local\Packages\5319275A.WhatsAppDesktop_cv1g1gvanyjgm\LocalState\sessions\A6A521C45BF54CB40C63CBB6383398495351B936\transfers\2026-02\income.csv")
df.head()
X = df.drop("Income($)",axis=1)
y = df["Income($)"]
cat = X.select_dtypes(include=["object"]).columns
num = X.select_dtypes(exclude=["object"]).columns
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
pre = ColumnTransformer(transformers=[
    ("catrical",OneHotEncoder(drop="first",handle_unknown="ignore"),cat),
    ("num",StandardScaler(),num)
])
pre
# Out:
# ColumnTransformer(transformers=[('catrical',
#                                  OneHotEncoder(drop='first',
#                                                handle_unknown='ignore'),
#                                  Index(['Name'], dtype='object')),
#                                 ('num', StandardScaler(),
#                                  Index(['Age'], dtype='object'))])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=30)
X_train.head()
model.fit(X_train,y_train)
y_pr = model.predict(X_test)
acc = r2_score(y_test,y_pr)
print(acc)
print(mean_squared_error(y_test,y_pr))
# Out:
# -0.4175249509729295
# 1826622651.823717
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
model = Pipeline(steps=[
    ("pre",pre),
    ("linear",LinearRegression())
])
model
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('catrical',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   Index(['Name'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['Age'], dtype='object'))])),
#                 ('linear', LinearRegression())])

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
live = pd.DataFrame({
    'Name':["Kory"], 
    'Age':[50]
})
pro = model.predict(live)
pro
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# array([51326.83859607])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, probplot
from sklearn.preprocessing import StandardScaler,MinMaxScaler,FunctionTransformer,LabelEncoder,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\gaurav\covid_toy.csv")
df.head()
df["fever"].fillna(df["fever"].mean(),inplace=True)

X = df.drop("fever",axis=1)
y =df["fever"]
cat = df.select_dtypes(include="object").columns
num = df.select_dtypes(exclude="object").columns
df.head()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_1432\1469271670.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["fever"].fillna(df["fever"].mean(),inplace=True)
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
pre = ColumnTransformer(transformers=[
    ("onehot",OneHotEncoder(drop="first"),cat),
    ("stand",StandardScaler(),num)
])
pre
# Out:
# ColumnTransformer(transformers=[('onehot', OneHotEncoder(drop='first'),
#                                  Index(['gender', 'cough', 'city', 'has_covid'], dtype='object')),
#                                 ('stand', StandardScaler(),
#                                  Index(['age'], dtype='object'))])

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=20)
model.fit(X_train,y_train)
y_pr = model.predict(X_test)
acc = r2_score(y_test,y_pr)
acc
# Out:
# -0.23270783067386525

# %%
model = Pipeline(steps=[
    ("pre",pre),
    ("linear",LinearRegression())
])
model
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('onehot',
#                                                   OneHotEncoder(drop='first'),
#                                                   Index(['gender', 'cough', 'city', 'has_covid'], dtype='object')),
#                                                  ('stand', StandardScaler(),
#                                                   Index(['age'], dtype='object'))])),
#                 ('linear', LinearRegression())])

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
live = pd.DataFrame({
    'age':[80], 
    'gender':["Male"],  
    'cough':["Strong"],
    'city':["Delhi"], 
    'has_covid':["Yes"]
})

# %%
probabilty  = model.predict(live)
prob_pos = probabilty[0],[1]
print(probabilty)
# Out:
# [99.65481553]
