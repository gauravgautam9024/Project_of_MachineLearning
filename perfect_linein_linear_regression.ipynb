# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler,FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error
print("this is squared"mean_squared_error
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\gaurav\tips.csv")
df.head()
plt.scatter(df["total_bill"],df["tip"])
plt.xlabel("total_bill")
plt.ylabel("tip")
df.head()
c = df[["total_bill","tip"]]
X = c.drop("tip",axis=1)
y = c["tip"]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=20)
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
""" perfect line """
plt.scatter(df['total_bill'],df['tip'])
plt.plot(X_train,model.predict(X_train),color='red')
plt.xlabel('total_bill')
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
print("this is mean absolute error",mean_absolute_error(y_pred,y_test))
print("this is squared",mean_squared_error(y_pred,y_test))
print("this is r2 score",r2_score(y_pred,y_test))
